# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280060-pixel/AMBAR/blob/main/ecuaciones_p1_al_p11_Ambar_Fierro_0060.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Ambar Fierro = 17 Fecha 15/abril/2026
#
# #### Problema 1: $X + 8 = 15$
# 1. Paso 1 (Identificar): Queremos dejar sola a la $X$. El $+8$ nos estorba.
# 2. Paso 2 (Transposición): El 8 que está sumando pasa al otro lado con la operación contraria: restando.$$X = 15 - 8$$
# 3. Paso 3 (Operar): Resolvemos la resta.$$X = 7$$

# %%
# Problema 1: X + 8 = 15
# Despeje: X = 15 - 8
#constante_derecha = 15
#valor_sumado = 8
constante_derecha = int(input("Ingresa el valor de la constante a la derecha: "))
valor_sumado = int(input("Ingresa el valor a sumar: "))

x = constante_derecha - valor_sumado
print(f"El resultado de X en el Problema 1 es: {x}")
# Out:
# Ingresa el valor de la constante a la derecha: 15
# Ingresa el valor a sumar: 8
# El resultado de X en el Problema 1 es: 7

# %% [markdown]
# #### Problema 3: $x + 4 = 21$
# Paso 1 (Simplificar): Como ambos términos tienen $X$, los sumamos ($3 + 4 = 7$).$$7X = 21$$Paso 2 (Transposición): El 7 está multiplicando a la $X$. Pasa al otro lado dividiendo.$$X = \frac{21}{7}$$Paso 3 (Operar): Resolvemos la división.$$X = 3$$

# %%
# Problema 3: X + 4 = 21
# Despeje: X = 21 - 4
#total = 21
#numero = 4
total = int(input("Ingresa el valor de la constante a la derecha: "))
numero = int(input("Ingresa el valor a restar: "))
x = total - numero
print(f"El resultado de X en el Problema 3 es: {x}")
# Out:
# Ingresa el valor de la constante a la derecha: 21
# Ingresa el valor a restar: 4
# El resultado de X en el Problema 3 es: 17

# %% [markdown]
# #### Problema 5: $6a - 2a + a = 20$
# 1. Paso 1 (Simplificar): Operamos los términos con la letra $a$. Recuerda que $+ a$ es lo mismo que $+ 1a$.$(6 - 2 + 1)a = 20$$$5a = 20$$
#
# 2.  Paso 2 (Transposición): El 5 que multiplica pasa dividiendo.$$a = \frac{20}{5}$$
#
# 3. Paso 3 (Operar):$$a = 4$$

# %%
# Problema 5: 6A - 2A + A = 20
# Simplificación de términos: (6 - 2 + 1)A = 5A
# Ecuación: 5A = 20 -> A = 20 / 5
#resultado_ecuacion = 20
#coeficiente_total = 6 - 2 + 1 # Suma de los coeficientes de A
resultado_ecuacion = int(input("Ingresa el valor de la constante a la derecha: "))
coeficiente_total = int(input("Ingresa el valor del coeficiente de A: "))
a = resultado_ecuacion / coeficiente_total
print(f"El resultado de A en el Problema 5 es: {int(a)}")
# Out:
# Ingresa el valor de la constante a la derecha: 20
# Ingresa el valor del coeficiente de A: 5
# El resultado de A en el Problema 5 es: 4

# %% [markdown]
# #### Problema 7: $4x + 3 = 2x + 11$
# Paso 1 (Simplificar izquierda): Sumamos las $X$ del lado izquierdo.$$7X = 2X + 11$$Paso 2 (Agrupar variables): El $2X$ está positivo (sumando) a la derecha, lo pasamos al lado izquierdo restando.$$7X - 2X = 11$$Paso 3 (Simplificar):$$5X = 11$$Paso 4 (Transposición): El 5 pasa dividiendo.$$X = \frac{11}{5}$$Paso 5 (Resultado decimal): $X = 2.2$

# %%
# Problema 7: 4X + 3 = 2X + 11
# Agrupamos X a la izquierda y números a la derecha: 4X - 2X = 11 - 3
# Simplificación: 2X = 8 -> X = 8 / 2
#dif_x = 4 - 2     # Coeficientes de X
#dif_num = 11 - 3  # Constantes
dif_x = int(input("Ingresa el valor del coeficiente de X: "))
dif_num = int(input("Ingresa el valor de la constante: "))
x = dif_num / dif_x
print(f"El resultado de X en el Problema 7 es: {int(x)}")
# Out:
# Ingresa el valor del coeficiente de X: 2
# Ingresa el valor de la constante: 8
# El resultado de X en el Problema 7 es: 4

# %% [markdown]
# #### Problema 9: $9m + 4 = 5m + 20$
# Paso 1 (Agrupar variables): Pasamos el $5M$ a la izquierda (restando) y el $+4$ a la derecha (restando).$$9M - 5M = -4$$Paso 2 (Simplificar):$$4M = -4$$Paso 3 (Transposición): El 4 que multiplica pasa dividiendo.$$M = \frac{-4}{4}$$Paso 4 (Operar): Aplicamos ley de signos (negativo entre positivo es negativo).$$M = -1$$

# %%
# Problema 9: 9M + 4 = 5M + 20
# Agrupamos: 9M - 5M = 20 - 4
# Simplificación: 4M = 16 -> M = 16 / 4
#m_izquierda = 9
#m_derecha = 5
#num_derecha = 20
#num_izquierda = 4
m_izquierda = int(input("Ingresa el valor del coeficiente de MIZQ: "))
m_derecha = int(input("Ingresa el valor del coeficiente de MDER: "))
num_derecha = int(input("Ingresa el valor de la constanteDER: "))
num_izquierda =int(input("Ingresa el valor de la constanteIZQ: "))

m = (num_derecha - num_izquierda) / (m_izquierda - m_derecha)
print(f"El resultado de M en el Problema 9 es: {int(m)}")
# Out:
# Ingresa el valor del coeficiente de MIZQ: 9
# Ingresa el valor del coeficiente de MDER: 5
# Ingresa el valor de la constanteDER: 20
# Ingresa el valor de la constanteIZQ: 4
# El resultado de M en el Problema 9 es: 4

# %% [markdown]
# #### Problema 11: $6a + 5 = 2a + 21$
# Paso 1 (Agrupar variables): Movemos el $2A$ a la izquierda restando.$$6A - 2A + 5 = 21$$Paso 2 (Agrupar constantes): Movemos el $+5$ a la derecha restando.$$6A - 2A = 21 - 5$$Paso 3 (Simplificar):$$4A = 16$$Paso 4 (Transposición): El 4 pasa dividiendo.$$A = \frac{16}{4}$$Paso 5 (Operar):$$A = 4$$

# %%
# Problema 11: 6A + 5 = 2A + 21
# Agrupamos: 6A - 2A = 21 - 5
# Simplificación: 4A = 16 -> A = 16 / 4
#coef_a1 = 6
#coef_a2 = 2
#num1 = 21
#num2 = 5
coef_a1 = int(input("Ingresa el valor del coeficiente de A1: "))
coef_a2 = int(input("Ingresa el valor del coeficiente de A2: "))
num1 = int(input("Ingresa el valor de la constante1: "))
num2 = int(input("Ingresa el valor de la constante2: "))

a = (num1 - num2) / (coef_a1 - coef_a2)
print(f"El resultado de A en el Problema 11 es: {int(a)}")
# Out:
# Ingresa el valor del coeficiente de A1: 6
# Ingresa el valor del coeficiente de A2: 2
# Ingresa el valor de la constante1: 21
# Ingresa el valor de la constante2: 5
# El resultado de A en el Problema 11 es: 4
